# %%
# Notes & Lecture by Akhona Njeje.
# Date : 15 Sept 2023.
# Topic : Blending Images & Thresholding.

import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img1 = cv2.imread('Real.webp')
img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
img2 = cv2.imread('Juve.jpg')
img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img1)

# %%
plt.imshow(img2)

# %%
img2.shape
# Out:
# (1200, 1200, 3)

# %%
x_off = 1200 - 700
y_off = 1200 - 700

# %%
img1.shape
# Out:
# (1612, 1200, 3)

# %%
rows, cols, channels = img1.shape

# %%
roi = img2[y_off:1200, x_off:1200]
plt.imshow(roi)

# %%
# Change img to grey.

img2gray = cv2.cvtColor(img2, cv2.COLOR_RGB2GRAY)
plt.imshow(img2gray, cmap='gray')

# %%
# Invesred of the image.

mask_inv = cv2.bitwise_not(img2gray)
plt.imshow(mask_inv)

# %%
mask_inv = cv2.bitwise_not(img2gray)
plt.imshow(mask_inv, cmap='gray')

# %%
# Thresholding.

img = cv2.imread('Blues.png')
plt.imshow(img)

# %%
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
# Read the img as a invesre.

img = cv2.imread('Blues.png', 0)
plt.imshow(img)

# %%
# Read the img as a gray.

img = cv2.imread('Blues.png', 0)
plt.imshow(img, cmap='gray')

# %%
def show(img):
    fig = plot.figure(figsize=(15,15))
    ax = fig.add_subplot(111)
    ax.imshow(img, cmap='gray')

# %%
show(img)
