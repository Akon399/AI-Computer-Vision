# %% [markdown]
# # Machine Intelligence, image processing.
# * 13 February 2024.
# * Research & solution by Mr Akhona Njeje.

# %%
import cv2
import matplotlib.pyplot as plt
import numpy
# %matplotlib inline

# %% [markdown]
# ### Open & process image for advance analysis.

# %%
pi = cv2.imread('pi.png')
show = cv2.cvtColor(pi, cv2.COLOR_BGR2RGB)
plt.imshow(pi)

# %%
ret, thresh1 = k, y
k, y = cv2.threshold(pi, 127, 255, cv2.THRESH_BINARY)
plt.imshow(k, y)

# %% [markdown]
# ### Apply a binary threshold onto the image.

# %% [markdown]
# * Notes :
#
# * Apply a binary threshold onto the images.Lets apply Binary Technique.
# * Thr(Threshold) & src(Pixel value).
# * Binary Thr, dst(x , y) = 0 if thr > src(x, y).
# * dst(x, y) = max value, if thr < src(x, y).
#
# * Binary inverse.
# * dst(x, y) = 0 if threshold < src(x, y).
# * dst(x, y) = max value, if threshold > src(x, y).

# %% [markdown]
# ### Conver its color space to HSV & display the image.

# %% [markdown]
# ### Create a low filter 4 x 4 kernel filled with values 1/10 & use 2D convolution to blur the image.

# %% [markdown]
# ### Create a horizontal filter with kernel size 5 to the gray scale version of the image & display the resulting gradient filtered version of thec image.

# %% [markdown]
# ### Plot Analysis in red, green & blue of the image. Use Histograms for Analysis.
