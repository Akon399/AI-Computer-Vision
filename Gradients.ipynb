# %%
# Notes & Solution by Akhona Njeje.
# Date : 11 Feb 2024.
# Topic : OpenCV Gradients.

# Notes:
# Gradients lead us to understanding object detection & tracking.
# Img gradient is a directional change in the color in an image. Theres algorithms that can track that directional movements.
# When you calculate x/y gradients, the image tends to change in color/texture.
# Math behind this application is Matrices.

import cv2
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
def display_img(img):
    fig = plt.figure(figsize=(12,10))
    ax = fig.add_subplot(111)
    ax = imshw(img, cmap='gray')

# %%
img = cv2.imread('C:/Users/User/Desktop/Ak Projects/AI/Robotics/Computer Vision/P4 Image Processing/Chess.jpg',0)
display_img(img)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 2
#       1 img = cv2.imread('C:/Users/User/Desktop/Ak Projects/AI/Robotics/Computer Vision/P4 Image Processing/Chess.jpg',0)
# ----> 2 display_img(img)
#
# Cell In[16], line 4, in display_img(img)
#       2 fig = plt.figure(figsize=(12,10))
#       3 ax = fig.add_subplot(111)
# ----> 4 ax = imshw(img, cmap='gray')
#
# NameError: name 'imshw' is not defined
